# %%
import sys
from pathlib import Path

project_root = Path("..").resolve()
sys.path.append(str(project_root))

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
from src.data import load_exoplanet_data

# %%
import pandas as pd

path = "../data/raw/exoplanets.csv"

df = pd.read_csv(path, sep=",", comment="#")
df.head()
# Out:
#    discoverymethod  disc_year   sy_dist
# 0  Radial Velocity       2007   93.1846
# 1  Radial Velocity       2007   93.1846
# 2  Radial Velocity       2007   93.1846
# 3  Radial Velocity       2009  125.3210
# 4  Radial Velocity       2009  125.3210

# %%
from src.data import load_exoplanet_data

# %%
from src.data import load_exoplanet_data
df = load_exoplanet_data("../data/raw/exoplanets.csv")
df.head()
# Out:
#    discoverymethod  disc_year   sy_dist
# 0  Radial Velocity       2007   93.1846
# 1  Radial Velocity       2007   93.1846
# 2  Radial Velocity       2007   93.1846
# 3  Radial Velocity       2009  125.3210
# 4  Radial Velocity       2009  125.3210

# %%
df.shape
# Out:
# (39251, 3)

# %%
df.columns
# Out:
# Index(['discoverymethod', 'disc_year', 'sy_dist'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39251 entries, 0 to 39250
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   discoverymethod  39251 non-null  object
#  1   disc_year        39251 non-null  int64
#  2   sy_dist          38405 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 920.1+ KB

# %%
df.head()
# Out:
#    discoverymethod  disc_year   sy_dist
# 0  Radial Velocity       2007   93.1846
# 1  Radial Velocity       2007   93.1846
# 2  Radial Velocity       2007   93.1846
# 3  Radial Velocity       2009  125.3210
# 4  Radial Velocity       2009  125.3210

# %%
features = ["discoverymethod","disc_year","sy_dist"]
